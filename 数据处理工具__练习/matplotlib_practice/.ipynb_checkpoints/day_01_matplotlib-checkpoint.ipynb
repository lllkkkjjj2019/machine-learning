# %% [markdown]
# ### 折线图绘制

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

# 指定中文字体
font = FontProperties(fname='/home/lin/PycharmProjects/machine_learning/数据挖掘/simhei.ttf')

# %%
import matplotlib.pyplot as plt
plt.figure()

# %%
plt.plot([1,0,9],[4,5,6])

# %%
plt.figure(figsize=(20,8),dpi=80)
plt.plot([1, 2, 3, 4, 5, 6, 7], [17, 17, 18, 15, 11, 11, 13])
plt.savefig("test1.png")

# %% [markdown]
# ### 完善原有折线图

# %%
import random
x = range(60)
y_shanghai = [random.uniform(15,18) for i in x]
y_beijin = [random.uniform(1,3) for i in x]

# %%
plt.figure(figsize=(20,8),dpi=80)
plt.plot(x,y_shanghai,color="r",linestyle="-.",label="shanghai")
plt.plot(x,y_beijin,color="b",label="beijin")
plt.legend()
x_label = ["11h{}m".format(i) for i in x]
plt.xticks(x[::5],x_label[::5])
plt.yticks(range(0,40,5))
plt.grid(True,linestyle="--",alpha=0.5)
plt.xlabel("time")
plt.ylabel("temp")
plt.title("TTT")
plt.show()
